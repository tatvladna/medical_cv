# %%
import os
import pydicom
import cv2
import numpy as np
import pandas as pd
from pathlib import Path
from ultralytics import YOLO
from tqdm import tqdm
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns

# -------------------------------------------------

MODEL_PATH = './yolov8m_med_final/final_best_model/weights/best.pt'
TEST_DATA_DIR = Path('./datatest')
OUTPUT_DIR = Path('./test_results')
DEFAULT_WINDOW_CENTER = 40 # общепринятые
DEFAULT_WINDOW_WIDTH = 400

# %%
def apply_windowing(dcm_image, window_center, window_width):
    pixel_array = dcm_image.pixel_array
    if 'RescaleSlope' in dcm_image and 'RescaleIntercept' in dcm_image:
        pixel_array = pixel_array * float(dcm_image.RescaleSlope) + float(dcm_image.RescaleIntercept)
    min_val = window_center - window_width / 2
    max_val = window_center + window_width / 2
    windowed_image = np.clip(pixel_array, min_val, max_val)
    normalized_image = ((windowed_image - min_val) / (max_val - min_val)) * 255
    return normalized_image.astype(np.uint8)

def main():
    output_pathologies_dir = OUTPUT_DIR / 'detected_pathologies'
    output_pathologies_dir.mkdir(parents=True, exist_ok=True)
    model = YOLO(MODEL_PATH)
    dcm_files = list(TEST_DATA_DIR.glob('**/*.dcm'))
    print(f"Найдено {len(dcm_files)} изображений для тестирования.")

    results_list = []

    for dcm_path in tqdm(dcm_files, desc="Обработка изображений"):
        try:
            actual_class = dcm_path.parent.name
            dcm = pydicom.dcmread(dcm_path)
            uid = dcm.SOPInstanceUID

            window_center = dcm.get('WindowCenter', DEFAULT_WINDOW_CENTER)
            window_width = dcm.get('WindowWidth', DEFAULT_WINDOW_WIDTH)
            if isinstance(window_center, pydicom.multival.MultiValue): window_center = window_center[0]
            if isinstance(window_width, pydicom.multival.MultiValue): window_width = window_width[0]

            processed_image_8bit = apply_windowing(dcm, window_center, window_width)
            bgr_image = cv2.cvtColor(processed_image_8bit, cv2.COLOR_GRAY2BGR)

            results = model.predict(bgr_image, verbose=False)
            
            # --- логика определения класса и УВЕРЕННОСТИ для ROC-AUC ---
            predicted_class = 'normal'
            confidence_score = 0.0 # уверенность по умолчанию для "нормы"
            
            if results[0].masks is not None and len(results[0].masks) > 0:
                predicted_class = 'pathology'
                # берем максимальную уверенность, если найдено несколько объектов
                confidence_score = results[0].boxes.conf.max().item()

            results_list.append({
                'uid': uid,
                'actual_class': actual_class,
                'predicted_class': predicted_class,
                'confidence_score': confidence_score
            })
            
            # --- сохраняем изображения только, если найдена патология ---
            if predicted_class == 'pathology':
                visualized_image = results[0].plot()
                output_image_path = output_pathologies_dir / f'{uid}_{actual_class}_pred_pathology.png'
                cv2.imwrite(str(output_image_path), visualized_image)

        except Exception as e:
            print(f"\nВ файле {dcm_path} ошибка: {e}")
        
    df = pd.DataFrame(results_list)
    csv_path = OUTPUT_DIR / 'results.csv'
    excel_path = OUTPUT_DIR / 'results.xlsx'
    df.to_csv(csv_path, index=False)
    df.to_excel(excel_path, index=False)
    
    print("\n--- Оценка производительности модели (на основе порога 0.25 по умолчанию) ---")
    y_true = df['actual_class']
    y_pred = df['predicted_class']
    print(f"Общая точность (Accuracy): {accuracy_score(y_true, y_pred):.2%}")
    print("\nМатрица ошибок (Confusion Matrix):")
    cm = confusion_matrix(y_true, y_pred, labels=['normal', 'pathology'])
    print(pd.DataFrame(cm, index=['Actual Normal', 'Actual Pathology'], columns=['Predicted Normal', 'Predicted Pathology']))
    
    y_true = df['actual_class']
    y_pred = df['predicted_class']
    labels = ['normal', 'pathology']
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels,
                annot_kws={"size": 16})
        
    plt.title('Матрица ошибок (Confusion Matrix)', fontsize=16)
    plt.ylabel('Истинный класс (True Label)', fontsize=12)
    plt.xlabel('Предсказанный класс (Predicted Label)', fontsize=12)
    plt.tight_layout()
    
    confusion_matrix_path = OUTPUT_DIR / 'confusion_matrix.png'
    plt.savefig(confusion_matrix_path)
    plt.close()

    #roc_auc
    print("\n--- Расчет ROC-AUC ---")
    y_true_binary = y_true.map({'normal': 0, 'pathology': 1})
    y_scores = df['confidence_score']
    
    fpr, tpr, _ = roc_curve(y_true_binary, y_scores)
    roc_auc = auc(fpr, tpr)
    
    print(f"ROC-AUC: {roc_auc:.4f}")

    # --- ROC-кривая ---
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc="lower right")
    roc_curve_path = OUTPUT_DIR / 'roc_curve.png'
    plt.savefig(roc_curve_path)
    plt.close()

# %%
main()
# Out:
# Найдено 100 изображений для тестирования.
# Обработка изображений:   0%|          | 0/100 [00:00<?, ?it/s]
# /home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.05010406111012071205150402080308'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:   2%|▏         | 2/100 [00:01<01:11,  1.36it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.08101202021204071400111105080708'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:   3%|▎         | 3/100 [00:01<00:44,  2.17it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.07151406040715060902051000001211'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:   4%|▍         | 4/100 [00:02<00:34,  2.79it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.02121312090009100603151203030502'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# /home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.05080712060806031512121402140015'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:   6%|▌         | 6/100 [00:02<00:20,  4.59it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.08060213041202110706110406080115'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:   9%|▉         | 9/100 [00:03<00:20,  4.35it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.08061200010806041212010607000605'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  11%|█         | 11/100 [00:03<00:15,  5.62it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.01060111030102090100140300150814'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# /home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.00120111100902131104141215051108'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  13%|█▎        | 13/100 [00:03<00:12,  7.03it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.02060901080113141209001304030002'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  14%|█▍        | 14/100 [00:03<00:13,  6.46it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.05010209081408140505151103130805'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  15%|█▌        | 15/100 [00:03<00:12,  6.61it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.00130413021208120905120506111200'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  17%|█▋        | 17/100 [00:03<00:09,  9.22it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.08020800120002061111131115071213'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  19%|█▉        | 19/100 [00:04<00:08,  9.39it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.00080911021306070104101003141003'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  21%|██        | 21/100 [00:04<00:12,  6.51it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.01120110070801080405130207101410'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# /home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.03021406031214151509021005100609'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  23%|██▎       | 23/100 [00:04<00:10,  7.44it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.08060800080504140704140902020807'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  24%|██▍       | 24/100 [00:04<00:09,  7.79it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.05150008051105051501120512080410'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  26%|██▌       | 26/100 [00:05<00:07,  9.47it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.02090501010310051402120011050305'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  35%|███▌      | 35/100 [00:06<00:08,  7.48it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.07070011130905131108071310081314'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  36%|███▌      | 36/100 [00:06<00:08,  7.36it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.00130507041313060907000107070909'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  38%|███▊      | 38/100 [00:06<00:07,  7.88it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.00120805010906140009011010140108'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# /home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.04001001131109131114070107131206'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  42%|████▏     | 42/100 [00:07<00:07,  7.87it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.04020205010200041206060710050606'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# /home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.00140008080800091507060113070700'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  46%|████▌     | 46/100 [00:07<00:06,  8.84it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.03110707020907030905041204111406'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  48%|████▊     | 48/100 [00:07<00:06,  7.82it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.09110805050305050012080208150503'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  52%|█████▏    | 52/100 [00:09<00:14,  3.31it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.08130908071315070511050215080609'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  53%|█████▎    | 53/100 [00:09<00:15,  3.07it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.03000310090111120509050215010710'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  54%|█████▍    | 54/100 [00:10<00:22,  2.06it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.00061104090400110710110506140006'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  55%|█████▌    | 55/100 [00:10<00:21,  2.09it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.00130403071010140504011409150312'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  56%|█████▌    | 56/100 [00:11<00:22,  1.95it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.06100614060407070100070202110304'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  57%|█████▋    | 57/100 [00:11<00:19,  2.17it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.02041111021300130807131513011512'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  58%|█████▊    | 58/100 [00:12<00:20,  2.05it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.01111307090803071111100004100501'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  59%|█████▉    | 59/100 [00:12<00:15,  2.59it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.02070504110200131415100200021513'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  61%|██████    | 61/100 [00:12<00:09,  3.95it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.07000404151213090515080801131000'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  62%|██████▏   | 62/100 [00:13<00:13,  2.91it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.08100806141307091410040103061003'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  63%|██████▎   | 63/100 [00:13<00:10,  3.54it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.01121311070201050604141207100013'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  65%|██████▌   | 65/100 [00:13<00:06,  5.59it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.07070404090911031314000115001000'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  66%|██████▌   | 66/100 [00:14<00:09,  3.52it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.09050010130712131403080203070203'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  67%|██████▋   | 67/100 [00:14<00:08,  3.94it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.05070515111504121203080005031111'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  70%|███████   | 70/100 [00:15<00:11,  2.72it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.03111407030913110514020305140513'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# /home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.06060605140512130610150009120811'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  72%|███████▏  | 72/100 [00:15<00:07,  3.88it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.07141311031008051506151202121302'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  74%|███████▍  | 74/100 [00:16<00:06,  4.18it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.02070810030907050308030811101406'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  75%|███████▌  | 75/100 [00:16<00:09,  2.72it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.09060202070912080901010402050503'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  77%|███████▋  | 77/100 [00:17<00:06,  3.77it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.06090308000105000814101211010208'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  79%|███████▉  | 79/100 [00:17<00:06,  3.22it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.04111304021302141313101510071406'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# /home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.04121208050310061301051204011513'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  81%|████████  | 81/100 [00:18<00:04,  3.84it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.03030904131109060413061405080806'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  84%|████████▍ | 84/100 [00:19<00:05,  2.81it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.07061400140610080610000013120301'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  86%|████████▌ | 86/100 [00:19<00:03,  4.01it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.06001300030008141006031105100101'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  87%|████████▋ | 87/100 [00:19<00:02,  4.56it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.04001109080302141501110005000306'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  89%|████████▉ | 89/100 [00:20<00:03,  2.81it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.04011414031107050307141312070408'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  90%|█████████ | 90/100 [00:21<00:03,  3.25it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.02091203140205050500070407081514'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  91%|█████████ | 91/100 [00:21<00:03,  2.64it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.02101105020907061500061514150204'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  92%|█████████▏| 92/100 [00:22<00:03,  2.41it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.04061212030010071207010715080208'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  93%|█████████▎| 93/100 [00:22<00:03,  2.32it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.07060205120713011400090000081500'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  94%|█████████▍| 94/100 [00:23<00:04,  1.47it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.07040107030301061000081006151111'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  95%|█████████▌| 95/100 [00:24<00:02,  1.79it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.01030601130814010008070914130809'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  96%|█████████▌| 96/100 [00:24<00:02,  1.95it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.01140900041000091504131512000804'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  97%|█████████▋| 97/100 [00:25<00:02,  1.48it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.02040212151315141513130303100312'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  98%|█████████▊| 98/100 [00:26<00:01,  1.61it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.06121005131404060305100209021507'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений:  99%|█████████▉| 99/100 [00:26<00:00,  1.74it/s]/home/pustovalova_tv/miniconda3/envs/data_med/lib/python3.10/site-packages/pydicom/valuerep.py:440: UserWarning: Invalid value for VR UI: '1.2.643.5.1.13.13.12.2.77.8252.02020402110307060109030911150509'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warn_and_log(msg)
# Обработка изображений: 100%|██████████| 100/100 [00:26<00:00,  3.71it/s]
# --- Оценка производительности модели (на основе порога 0.25 по умолчанию) ---
# Общая точность (Accuracy): 77.00%
#
# Матрица ошибок (Confusion Matrix):
#                   Predicted Normal  Predicted Pathology
# Actual Normal                   49                    1
# Actual Pathology                22                   28
#
# --- Расчет ROC-AUC ---
# ROC-AUC: 0.7712
